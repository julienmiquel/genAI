# %%
"""
encoding = base64.b64encode(open(img_path, 'rb').read())
The following function takes an image file path and returns a base64 encoded image as string
"""
def encode_image(img_path):
    with open(img_path, "rb") as img_file:
        encoded_str = base64.b64encode(img_file.read())
    return encoded_str

"""
decoding = base64.b64decode(encoding)
The following function takes a base64 encoded image and returns a PIL image
"""
def decode_image(img_base64):
    img_bytes = base64.b64decode(img_base64)
    return Image.open(BytesIO(img_bytes))

"""
display_image = decode_image(encoding)
The following function takes a PIL image and displays it
"""
def display_image(img):
    display.display(img)
    display.clear_output(wait=True)

"""
Read files from GCS bucket for a given path.
"""
def read_file_from_gcs(bucket_name, file_path):
    print("calling read_file_from_gcs")
    storage_client = storage.Client()
    bucket = storage_client.get_bucket(bucket_name)
    blob = bucket.blob(file_path)
    return blob

"""
Read Json Config file from GCS bucket
"""
def read_json_from_gcs(bucket_name, file_path):
    blob = read_file_from_gcs(bucket_name, file_path)
    str_json = blob.download_as_string()
    print(str_json)
    json_config = json.loads(str_json)
    return json_config


def process(headers, req_obj):
    response = requests.post(f'{IMAGE_GEN_ENDPOINT_URI}', data=json.dumps(req_obj), headers=headers)
    json_response = json.loads(response.text)
    try:
        prediction = json_response['predictions']
        return prediction
    except:
        print(response.text)
        print(dir(response))

# %%
# @title Prediction for the Logo
prompt = f"""Design of abstract logo featuring a dog in blue on a pink background. 
Include lines as an additional design element. """

print(prompt)
response = generate_image(prompt,
                                    size, # sampleImageSize
                                    4, # sampleCount
                                    0  # seed
                                    )
print(response)
json_response = json.loads(response.text)
predictions = json_response['predictions']
display_images(predictions,size,1)

# %%
# Sample prompts to test out and add to the form in the next cell
Prompts = [
 'mini planet with new york in metallic iridescent material, 3D render, isometric perspective on dark background',
 'origami dancer in white paper, 3D render, ultra-detailed, on white background, studio shot' , # this yields policy violation
 'a square watermelon in a beach on a sunset.',
 'studio shot of fantasy object, white coffee cup, multiple handles similar to octopus, white background',
 'A studio shot of shoes made out of stringy noodles, ultra-detailed, on white background',
 'audacious and whimsical fantasy house shaped like pasion fruit with windows and door, in the desert'
]

size = 512
for prompt in Prompts:
    print(prompt)
    response = generate_image(prompt,
                                        size, # sampleImageSize
                                        4, # sampleCount
                                        0  # seed
                                        )
    print(response)
    json_response = json.loads(response.text)
    predictions = json_response['predictions']
    display_images(predictions,size,1)

# %%
Prompts = [

"a duffle bag made of cheese",

"neon tubes in the shape of a bird",

"an armchair made of paper, studio photo, origami style"
]

size = 512
for prompt in Prompts:
    print(prompt)
    response = generate_image(prompt,
                                        size, # sampleImageSize
                                        4, # sampleCount
                                        0  # seed
                                        )
    print(response)
    json_response = json.loads(response.text)
    predictions = json_response['predictions']
    display_images(predictions,size,1)

# %%
# @title Prediction for the Logo
prompt = f"""Design of abstract logo featuring a dog in blue on a pink background. 
Include lines as an additional design element. """

print(prompt)
response = generate_image(prompt,
                                    size, # sampleImageSize
                                    4, # sampleCount
                                    0  # seed
                                    )
print(response)
json_response = json.loads(response.text)
predictions = json_response['predictions']
display_images(predictions,size,1)

# %%
# Sample prompts to test out and add to the form in the next cell
Prompts = [
 'mini planet with new york in metallic iridescent material, 3D render, isometric perspective on dark background',
 'origami dancer in white paper, 3D render, ultra-detailed, on white background, studio shot' , # this yields policy violation
 'a square watermelon in a beach on a sunset.',
 'studio shot of fantasy object, white coffee cup, multiple handles similar to octopus, white background',
 'A studio shot of shoes made out of stringy noodles, ultra-detailed, on white background',
 'audacious and whimsical fantasy house shaped like pasion fruit with windows and door, in the desert'
]

size = 512
for prompt in Prompts:
    print(prompt)
    response = generate_image(prompt,
                                        size, # sampleImageSize
                                        4, # sampleCount
                                        0  # seed
                                        )
    print(response)
    json_response = json.loads(response.text)
    predictions = json_response['predictions']
    display_images(predictions,size,1)

# %%
Prompts = [

"a duffle bag made of cheese",

"neon tubes in the shape of a bird",

"an armchair made of paper, studio photo, origami style"
]

size = 512
for prompt in Prompts:
    print(prompt)
    response = generate_image(prompt,
                                        size, # sampleImageSize
                                        4, # sampleCount
                                        0  # seed
                                        )
    print(response)
    json_response = json.loads(response.text)
    predictions = json_response['predictions']
    display_images(predictions,size,1)

# %%
"""
encoding = base64.b64encode(open(img_path, 'rb').read())
The following function takes an image file path and returns a base64 encoded image as string
"""
def encode_image(img_path):
    with open(img_path, "rb") as img_file:
        encoded_str = base64.b64encode(img_file.read())
    return encoded_str

"""
decoding = base64.b64decode(encoding)
The following function takes a base64 encoded image and returns a PIL image
"""
def decode_image(img_base64):
    img_bytes = base64.b64decode(img_base64)
    return Image.open(BytesIO(img_bytes))

"""
display_image = decode_image(encoding)
The following function takes a PIL image and displays it
"""
def display_image(img):
    display.display(img)
    display.clear_output(wait=True)

"""
Read files from GCS bucket for a given path.
"""
def read_file_from_gcs(bucket_name, file_path):
    print("calling read_file_from_gcs")
    storage_client = storage.Client()
    bucket = storage_client.get_bucket(bucket_name)
    blob = bucket.blob(file_path)
    return blob

"""
Read Json Config file from GCS bucket
"""
def read_json_from_gcs(bucket_name, file_path):
    blob = read_file_from_gcs(bucket_name, file_path)
    str_json = blob.download_as_string()
    print(str_json)
    json_config = json.loads(str_json)
    return json_config


def process(headers, req_obj):
    response = requests.post(f'{IMAGE_GEN_ENDPOINT_URI}', data=json.dumps(req_obj), headers=headers)
    json_response = json.loads(response.text)
    try:
        prediction = json_response['predictions']
        return prediction
    except:
        print(response.text)
        print(dir(response))

# %%
# @title Prediction for the Logo
prompt = f"""Design of abstract logo featuring a dog in blue on a pink background. 
Include lines as an additional design element. """

print(prompt)
response = generate_image(prompt,
                                    size, # sampleImageSize
                                    4, # sampleCount
                                    0  # seed
                                    )
print(response)
json_response = json.loads(response.text)
predictions = json_response['predictions']
display_images(predictions,size,1)

# %%
# Sample prompts to test out and add to the form in the next cell
Prompts = [
 'mini planet with new york in metallic iridescent material, 3D render, isometric perspective on dark background',
 'origami dancer in white paper, 3D render, ultra-detailed, on white background, studio shot' , # this yields policy violation
 'a square watermelon in a beach on a sunset.',
 'studio shot of fantasy object, white coffee cup, multiple handles similar to octopus, white background',
 'A studio shot of shoes made out of stringy noodles, ultra-detailed, on white background',
 'audacious and whimsical fantasy house shaped like pasion fruit with windows and door, in the desert'
]

size = 512
for prompt in Prompts:
    print(prompt)
    response = generate_image(prompt,
                                        size, # sampleImageSize
                                        4, # sampleCount
                                        0  # seed
                                        )
    print(response)
    json_response = json.loads(response.text)
    predictions = json_response['predictions']
    display_images(predictions,size,1)

# %%
Prompts = [

"a duffle bag made of cheese",

"neon tubes in the shape of a bird",

"an armchair made of paper, studio photo, origami style"
]

size = 512
for prompt in Prompts:
    print(prompt)
    response = generate_image(prompt,
                                        size, # sampleImageSize
                                        4, # sampleCount
                                        0  # seed
                                        )
    print(response)
    json_response = json.loads(response.text)
    predictions = json_response['predictions']
    display_images(predictions,size,1)

# %%
# @title Prediction for the Logo
prompt = f"""Design of abstract logo featuring a dog in blue on a pink background. 
Include lines as an additional design element. """

print(prompt)
response = generate_image(prompt,
                                    size, # sampleImageSize
                                    4, # sampleCount
                                    0  # seed
                                    )
print(response)
json_response = json.loads(response.text)
predictions = json_response['predictions']
display_images(predictions,size,1)

# %%
# Sample prompts to test out and add to the form in the next cell
Prompts = [
 'mini planet with new york in metallic iridescent material, 3D render, isometric perspective on dark background',
 'origami dancer in white paper, 3D render, ultra-detailed, on white background, studio shot' , # this yields policy violation
 'a square watermelon in a beach on a sunset.',
 'studio shot of fantasy object, white coffee cup, multiple handles similar to octopus, white background',
 'A studio shot of shoes made out of stringy noodles, ultra-detailed, on white background',
 'audacious and whimsical fantasy house shaped like pasion fruit with windows and door, in the desert'
]

size = 512
for prompt in Prompts:
    print(prompt)
    response = generate_image(prompt,
                                        size, # sampleImageSize
                                        4, # sampleCount
                                        0  # seed
                                        )
    print(response)
    json_response = json.loads(response.text)
    predictions = json_response['predictions']
    display_images(predictions,size,1)

# %%
Prompts = [

"a duffle bag made of cheese",

"neon tubes in the shape of a bird",

"an armchair made of paper, studio photo, origami style"
]

size = 512
for prompt in Prompts:
    print(prompt)
    response = generate_image(prompt,
                                        size, # sampleImageSize
                                        4, # sampleCount
                                        0  # seed
                                        )
    print(response)
    json_response = json.loads(response.text)
    predictions = json_response['predictions']
    display_images(predictions,size,1)
